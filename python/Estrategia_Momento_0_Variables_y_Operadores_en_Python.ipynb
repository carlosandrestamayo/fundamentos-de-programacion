# %% [markdown]
# # 📘 **Estrategia de Mejoramiento - Momento 0**
#
# ---
# ![Python Logo](https://www.python.org/static/community_logos/python-logo.png)
# ### **Fundamentos de Programación**
# ### *Variables, Tipos de Datos y Operadores en Python*
#
# ---
#
# <div align="center">
#
# <!--<img src="https://upload.wikimedia.org/wikipedia/commons/c/c3/Python-logo-notext.svg" alt="Python Logo" width="60"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://scikit-learn.org/stable/_static/scikit-learn-logo-small.png" alt="Scikit-learn Logo" width="120"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://matplotlib.org/_static/images/logo2.svg" alt="Matplotlib Logo" width="120"/>
# <img src="https://seaborn.pydata.org/_static/logo-wide-lightbg.svg" alt="Seaborn Logo" width="200"/>-->
#
# </div>
#
# ---
#
# ### 👨‍🏫 **Autores:**
# **Carlos Andrés Tamayo Benjumea**
# Ingeniero de Sistemas | Especialista en Inteligencia Artificial | Docente Universitario
#
# **Rosiris Consuelo Padilla Sierra**
# Ingeniero de Sistemas | Magister en TIC para la Educación | Docente Universitario
#
# **Luis Manuel Palmera Quintero**
# Ingeniero de Sistemas | Doctor en Ciencias de la Educación | Docente Universitario
#
# **José Javier Coronel Casadiego**
# Ingeniero de Sistemas | Especialista en Docencia Universitaria | Docente Universitario
#
#
#
#
# ---
#
# ### 🛠️ **Herramientas Utilizadas:**
# - Python
# - Google Colab
#
# ---
#
# ### 🎯 **Propósito:**
# Comprender el uso de las `Variables, Tipos de Datos y Operadores` para resolver problemas de forma lógica y estructurada
#
# ---
#
# ### 📅 **Fecha:**
# 25 de Septiembre de 2025
#
# ---

# %% [markdown]
# # 🧮 Variables, Tipos de Datos y Operadores en Python
#
# Python es un lenguaje **dinámico y flexible**, donde no es necesario declarar el tipo de dato al crear una variable.
# El tipo se asigna automáticamente según el valor que contenga.
#
# ---
#
# # 🔤 Variables en Python
#
# ## 🧩 Qué es una variable
#
# Una **variable** es un espacio en memoria donde se guarda información que puede cambiar durante la ejecución del programa.
#
# ```python
# nombre = "Carlos"
# edad = 25
# estatura = 1.75
# es_estudiante = True
# ```
#
# En este ejemplo:
# - `nombre` guarda un texto → tipo **`str`** (cadena)
# - `edad` guarda un número entero → tipo **`int`**
# - `estatura` guarda un número decimal → tipo **`float`**
# - `es_estudiante` guarda un valor lógico → tipo **`bool`**
#
# ---
#
# # 🧠 Tipos de datos básicos en Python
#
# | Tipo de dato | Descripción | Ejemplo | Resultado de `type()` |
# |---------------|--------------|----------|-------------------------|
# | `int` | Números enteros, sin decimales | `x = 10` | `<class 'int'>` |
# | `float` | Números decimales (con punto) | `x = 3.14` | `<class 'float'>` |
# | `str` | Texto o cadena de caracteres | `x = "Hola"` | `<class 'str'>` |
# | `bool` | Valores lógicos: Verdadero o Falso | `x = True` | `<class 'bool'>` |
# | `list` | Lista de valores ordenados y modificables | `x = [1, 2, 3]` | `<class 'list'>` |
# | `tuple` | Lista ordenada e inmutable | `x = (1, 2, 3)` | `<class 'tuple'>` |
# | `dict` | Colección de pares clave:valor | `x = {"nombre": "Ana", "edad": 20}` | `<class 'dict'>` |
#
# 📘 **Ejemplo:**
#
# ```python
# nombre = "María"
# edad = 22
# promedio = 4.3
# es_aprobado = True
#
# print(type(nombre))
# print(type(edad))
# print(type(promedio))
# print(type(es_aprobado))
# ```
#
# 📤 **Salida:**
# ```
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# ```
#
# ---
#
# # 📦 Reglas para nombrar variables
#
# ✅ Puede contener letras, números y guiones bajos (`_`)
# 🚫 No puede comenzar con un número
# 🚫 No puede tener espacios ni caracteres especiales
# ⚠️ Python distingue entre mayúsculas y minúsculas (`Edad` ≠ `edad`)
#
# ---
#
# # ➕ Operadores Aritméticos
#
# Los operadores **aritméticos** permiten realizar cálculos matemáticos.
#
# | Operador | Descripción | Ejemplo | Resultado |
# |-----------|--------------|----------|------------|
# | `+` | Suma | `5 + 3` | `8` |
# | `-` | Resta | `9 - 4` | `5` |
# | `*` | Multiplicación | `6 * 7` | `42` |
# | `/` | División (decimal) | `8 / 2` | `4.0` |
# | `//` | División entera | `8 // 3` | `2` |
# | `%` | Módulo (residuo) | `10 % 3` | `1` |
# | `**` | Potencia | `2 ** 3` | `8` |
#
# 📘 **Ejemplo:**
#
# ```python
# a = 10
# b = 3
# print("Suma:", a + b)
# print("Resta:", a - b)
# print("Multiplicación:", a * b)
# print("División:", a / b)
# print("División entera:", a // b)
# print("Residuo:", a % b)
# print("Potencia:", a ** b)
# ```
#
# ---
#
# # ⚖️ Operadores Relacionales
#
# Se utilizan para **comparar valores**.
# El resultado será **True** (verdadero) o **False** (falso).
#
# | Operador | Descripción | Ejemplo | Resultado |
# |-----------|--------------|----------|------------|
# | `==` | Igual a | `5 == 5` | `True` |
# | `!=` | Diferente de | `5 != 3` | `True` |
# | `>` | Mayor que | `7 > 2` | `True` |
# | `<` | Menor que | `3 < 1` | `False` |
# | `>=` | Mayor o igual que | `5 >= 5` | `True` |
# | `<=` | Menor o igual que | `4 <= 2` | `False` |
#
# 📘 **Ejemplo:**
#
# ```python
# x = 10
# y = 20
# print("¿x es igual a y?", x == y)
# print("¿x es menor que y?", x < y)
# print("¿x es mayor o igual que y?", x >= y)
# ```
#
# ---
#
# # 🔗 Operadores Lógicos
#
# Permiten combinar varias condiciones.
#
# | Operador | Significado | Ejemplo | Resultado |
# |-----------|--------------|----------|------------|
# | `and` | Verdadero si **ambas** son verdaderas | `(5 > 2 and 3 < 4)` | `True` |
# | `or` | Verdadero si **una** es verdadera | `(5 < 2 or 4 > 1)` | `True` |
# | `not` | Invierte el valor lógico | `not(5 > 2)` | `False` |
#
# 📘 **Ejemplo:**
#
# ```python
# edad = 18
# tiene_permiso = True
#
# if edad >= 18 and tiene_permiso:
#     print("Puedes ingresar ✅")
# else:
#     print("Acceso denegado ❌")
# ```
#
# ---
#
# # 🖨️ La función `print()` en Python
#
# La función **`print()`** se usa para **mostrar información en pantalla**.
# Puede mostrar texto, variables o resultados de operaciones.
#
# ---
#
# ## 📘 Ejemplo básico
#
# ```python
# nombre = "Ana"
# edad = 20
# print("Hola,", nombre)
# print("Tienes", edad, "años.")
# ```
#
# 📤 **Salida:**
# ```
# Hola, Ana
# Tienes 20 años.
# ```
#
# ---
#
# ## 🧩 Formas de mostrar texto con `print()`
#
# ### 🔹 Usando comas
# ```python
# print("El precio es", 50, "pesos")
# ```
#
# ### 🔹 Usando concatenación con `+`
# ```python
# print("El precio es " + str(50) + " pesos")
# ```
#
# ### 🔹 Usando f-strings (forma moderna)
# ```python
# precio = 50
# print(f"El precio es {precio} pesos")
# ```
#
# 📤 **Salida:**
# ```
# El precio es 50 pesos
# ```
#
# ---
#
# # 💡 Reto de práctica
#
# Crea un programa que:
#
# 1. Pida al usuario su **nombre** (`str`), **edad** (`int`) y **nota final** (`float`).
# 2. Muestre un mensaje como:
#
# ```
# Hola, Laura. Tienes 22 años y tu nota final es 4.5
# ```
#
# 3. Luego evalúe:
#    - Si la nota es mayor o igual a 3.0 → `"Aprobaste ✅"`
#    - Si no → `"Reprobaste ❌"`
#
# 👉 Usa `f-strings` para construir el mensaje final.

# %% [markdown]
# # ⌨️ La función `input()` en Python
#
# La función **`input()`** se usa para **recibir información del usuario** mientras el programa está en ejecución.
# Permite que el usuario escriba datos desde el teclado, los cuales se almacenan en una variable.
#
# ---
#
# ## 🧩 Sintaxis básica
#
# ```python
# variable = input("Mensaje para el usuario: ")
# ```
#
# 📘 **Ejemplo:**
#
# ```python
# nombre = input("¿Cómo te llamas? ")
# print("Hola,", nombre)
# ```
#
# 📤 **Salida:**
#
# ```
# ¿Cómo te llamas? Carlos
# Hola, Carlos
# ```
#
# ---
#
# ## 🎯 Concepto clave
#
# > Todo lo que se obtiene con `input()` **siempre se guarda como texto** (tipo `str`),
# > aunque el usuario escriba un número.
#
# Por eso, cuando queremos **usar valores numéricos** (sumar, restar, comparar…),
# debemos **convertir ese texto** a un número usando `int()` o `float()`.
#
# ---
#
# # 🔢 La función `int()` en Python
#
# La función **`int()`** convierte un texto (cadena) o número decimal en un **entero**.
# Sirve cuando el dato ingresado no tiene decimales y lo necesitamos como número para cálculos.
#
# ---
#
# ## 🧩 Sintaxis básica
#
# ```python
# numero = int(input("Ingrese un número entero: "))
# ```
#
# 📘 **Ejemplo:**
#
# ```python
# edad = int(input("¿Cuántos años tienes? "))
# print("El próximo año tendrás", edad + 1, "años.")
# ```
#
# 📤 **Salida:**
#
# ```
# ¿Cuántos años tienes? 15
# El próximo año tendrás 16 años.
# ```
#
# ---
#
# ## ⚠️ Importante
#
# - Si el usuario escribe algo que **no sea un número entero**, el programa mostrará un error.
# - `int()` **elimina los decimales** (por ejemplo, `int(7.9)` → `7`).
#
# ---
#
# # 🔣 La función `float()` en Python
#
# La función **`float()`** convierte un texto o número en un **decimal (número con coma o punto)**.
# Se usa cuando queremos trabajar con valores que **no son enteros**, como precios, notas o medidas.
#
# ---
#
# ## 🧩 Sintaxis básica
#
# ```python
# numero = float(input("Ingrese un número decimal: "))
# ```
#
# 📘 **Ejemplo:**
#
# ```python
# nota = float(input("Ingrese su nota final: "))
# if nota >= 3.0:
#     print("Aprobaste ✅")
# else:
#     print("Reprobaste ❌")
# ```
#
# 📤 **Salida:**
#
# ```
# Ingrese su nota final: 4.2
# Aprobaste ✅
# ```
#
# ---
#
# # 🧠 En resumen
#
# | Función | Significado | Tipo de dato que devuelve | Ejemplo |
# |----------|--------------|---------------------------|----------|
# | `input()` | Pide un dato al usuario | Texto (`str`) | `"25"` |
# | `int()` | Convierte texto en número entero | Entero (`int`) | `25` |
# | `float()` | Convierte texto en número decimal | Decimal (`float`) | `25.0` |
#
# ---
#
# # 💡 Reto de práctica
#
# Crea un programa que:
#
# 1. Pida al usuario su **nombre**.
# 2. Le solicite su **edad actual** (como entero).
# 3. Le pida su **estatura en metros** (como decimal).
# 4. Finalmente, muestre un mensaje como:
#
# ```
# Hola, Ana. Tienes 20 años y mides 1.65 metros.
# ```

# %% [markdown]
# # ⚙️ Operadores de Asignación y Pertenencia en Python
#
# ---
#
# # 🔄 Operadores de Asignación
#
# Los **operadores de asignación** permiten modificar el valor de una variable
# sin tener que escribir la variable dos veces.
#
# 📘 **Ejemplo tradicional:**
#
# ```python
# x = 10
# x = x + 1  # incrementa en 1
# print(x)
# ```
#
# 📤 **Salida:**
# ```
# 11
# ```
#
# ---
#
# ## 🚀 Forma corta con operadores de asignación
#
# Python permite escribir lo mismo de forma más compacta:
#
# | Operador | Descripción | Ejemplo | Equivale a |
# |-----------|--------------|----------|-------------|
# | `+=` | Suma y asigna | `x += 2` | `x = x + 2` |
# | `-=` | Resta y asigna | `x -= 3` | `x = x - 3` |
# | `*=` | Multiplica y asigna | `x *= 4` | `x = x * 4` |
# | `/=` | Divide y asigna | `x /= 2` | `x = x / 2` |
# | `//=` | División entera y asigna | `x //= 3` | `x = x // 3` |
# | `%=` | Módulo y asigna | `x %= 5` | `x = x % 5` |
# | `**=` | Potencia y asigna | `x **= 2` | `x = x ** 2` |
#
# ---
#
# ## ❌ ¿Funciona `i++` en Python?
#
# No.
# Python **no tiene operadores de incremento o decremento automáticos** (`++` o `--`).
#
# 📘 **Incorrecto:**
# ```python
# i = 0
# i++  # ❌ Error de sintaxis
# ```
#
# 📗 **Correcto:**
# ```python
# i = 0
# i += 1  # ✅ Incrementa en 1
# print(i)
# ```
#
# 📤 **Salida:**
# ```
# 1
# ```
#
# ---
#
# # 🔍 Operadores de Pertenencia (`in`, `not in`)
#
# Los **operadores de pertenencia** permiten verificar si un elemento
# se encuentra dentro de una secuencia (lista, cadena, tupla…).
#
# ---
#
# ## 🧩 Sintaxis básica
#
# ```python
# elemento in secuencia
# elemento not in secuencia
# ```
#
# 📘 **Ejemplo con cadenas:**
#
# ```python
# frase = "Aprender Python es divertido"
#
# print("Python" in frase)      # True
# print("java" in frase)        # False
# print("C++" not in frase)     # True
# ```
#
# 📤 **Salida:**
# ```
# True
# False
# True
# ```
#
# ---
#
# ## 🧩 Ejemplo con listas
#
# ```python
# numeros = [1, 2, 3, 4, 5]
#
# print(3 in numeros)        # True
# print(10 not in numeros)   # True
# ```
#
# 📤 **Salida:**
# ```
# True
# True
# ```
#
# ---
#
# # 💡 Reto de práctica
#
# 1. Crea una lista con los nombres de tus amigos.
# 2. Pide al usuario que ingrese un nombre.
# 3. Usa `in` o `not in` para verificar si está en la lista.
# 4. Muestra un mensaje según el resultado.
#
# 👉 Ejemplo de salida:
#
# ```
# Ingrese un nombre: Ana
# Ana sí está en la lista ✅
# ```
#
# ---
#
# # 🧠 En resumen
#
# | Tipo | Operadores | Uso principal |
# |------|-------------|----------------|
# | Asignación | `=`, `+=`, `-=`, `*=`, `/=`, `**=` | Modificar valores de variables |
# | Pertenencia | `in`, `not in` | Verificar si un elemento pertenece a una secuencia |
# | Incremento | `i += 1` | Python **no usa** `i++` |

# %% [markdown]
# # 📘 Ejercicios básicos de matemáticas con operadores aritméticos en Python
#
# ---
#
# ## 🔹 Nivel 1: Operaciones básicas
#
# ### 📝 Ejercicio 1: Suma de dos números
# Crea un programa que pida **dos números** y muestre la **suma** de ambos.
#
# 👉 Ejemplo:
# ```
# Ingrese el primer número: 8
# Ingrese el segundo número: 5
# La suma es: 13
# ```
#
# ---
#
# ### 📝 Ejercicio 2: Resta de dos números
# Pide dos números y muestra el resultado de **restar el segundo al primero**.
#
# 👉 Ejemplo:
# ```
# Ingrese el primer número: 10
# Ingrese el segundo número: 3
# La resta es: 7
# ```
#
# ---
#
# ### 📝 Ejercicio 3: Multiplicación de dos números
# Crea un programa que solicite dos números y muestre su **producto**.
#
# 👉 Ejemplo:
# ```
# Ingrese el primer número: 4
# Ingrese el segundo número: 6
# El resultado de la multiplicación es: 24
# ```
#
# ---
#
# ### 📝 Ejercicio 4: División de dos números
# Haz un programa que pida dos números y muestre la **división del primero entre el segundo**.
#
# 👉 Recuerda que en Python `/` devuelve un número con decimales.
#
# Ejemplo:
# ```
# Ingrese el dividendo: 9
# Ingrese el divisor: 2
# El resultado de la división es: 4.5
# ```
#
# ---
#
# ## 🔹 Nivel 2: Operaciones combinadas
#
# ### 📝 Ejercicio 5: Promedio de tres números
# Pide tres números al usuario y calcula su **promedio**.
#
# 👉 Fórmula:
# ```
# promedio = (num1 + num2 + num3) / 3
# ```
#
# Ejemplo:
# ```
# Ingrese tres notas: 4.0, 3.5, 5.0
# El promedio es: 4.17
# ```
#
# ---
#
# ### 📝 Ejercicio 6: Potencia de un número
# Pide un número base y un exponente, y calcula la **potencia** usando `**`.
#
# 👉 Ejemplo:
# ```
# Ingrese la base: 2
# Ingrese el exponente: 4
# El resultado es: 16
# ```
#
# ---
#
# ### 📝 Ejercicio 7: División entera y residuo
# Solicita dos números enteros al usuario y muestra:
# - La **división entera** usando `//`
# - El **residuo** usando `%`
#
# 👉 Ejemplo:
# ```
# Ingrese el dividendo: 10
# Ingrese el divisor: 3
# División entera: 3
# Residuo: 1
# ```
#
# ---
#
# ### 📝 Ejercicio 8: Área de un triángulo
# Pide la **base** y la **altura** de un triángulo, y calcula su **área** usando la fórmula:
#
# ```
# área = (base * altura) / 2
# ```
#
# 👉 Ejemplo:
# ```
# Base: 8
# Altura: 5
# Área del triángulo: 20.0
# ```
#
# ---
#
# ## 🔹 Nivel 3: Aplicaciones simples
#
# ### 📝 Ejercicio 9: Conversión de grados Celsius a Fahrenheit
# Crea un programa que pida una temperatura en Celsius y la convierta a Fahrenheit.
#
# 👉 Fórmula:
# ```
# F = (C * 9/5) + 32
# ```
#
# Ejemplo:
# ```
# Ingrese la temperatura en °C: 25
# Equivale a 77.0 °F
# ```
#
# ---
#
# ### 📝 Ejercicio 10: Cálculo del total a pagar
# Pide el precio de un producto y el número de unidades.
# Calcula el **total a pagar** multiplicando ambos valores.
#
# 👉 Ejemplo:
# ```
# Precio del producto: 1200
# Cantidad: 4
# Total a pagar: 4800
# ```
#
# ---
#
# ### 📝 Ejercicio 11: Cálculo del perímetro de un rectángulo
# Solicita la **base** y la **altura** del rectángulo y muestra su **perímetro**.
#
# 👉 Fórmula:
# ```
# perímetro = 2 * (base + altura)
# ```
#
# Ejemplo:
# ```
# Base: 5
# Altura: 3
# Perímetro: 16
# ```
#
# ---
#
# ### 📝 Ejercicio 12: Conversión de minutos a horas
# Pide una cantidad de minutos y conviértela a horas.
#
# 👉 Fórmula:
# ```
# horas = minutos / 60
# ```
#
# Ejemplo:
# ```
# Ingrese los minutos: 150
# Equivale a 2.5 horas
# ```
#
# ---
#
# ### 📝 Ejercicio 13: Cálculo de salario semanal
# Pide el valor de la hora y la cantidad de horas trabajadas.
# Calcula el **salario total** de la semana.
#
# 👉 Ejemplo:
# ```
# Valor de la hora: 8000
# Horas trabajadas: 40
# Salario total: 320000
# ```
#
# ---
#
# ### 📝 Ejercicio 14: Conversión de pesos a dólares
# Pide una cantidad en **pesos colombianos** y el valor del **dólar**.
# Calcula cuántos dólares equivalen.
#
# 👉 Ejemplo:
# ```
# Pesos: 500000
# Valor del dólar: 4000
# Equivale a 125.0 dólares
# ```
#
# ---
#
# ### 📝 Ejercicio 15: Calcular velocidad promedio
# Crea un programa que pida **distancia recorrida (km)** y **tiempo (h)**,
# y calcule la **velocidad promedio** usando la fórmula:
#
# ```
# velocidad = distancia / tiempo
# ```
#
# Ejemplo:
# ```
# Distancia: 120
# Tiempo: 2
# Velocidad promedio: 60 km/h
# ```

# %% [markdown]
# # 🧩 Métodos y funciones más comunes para trabajar con cadenas de texto (`str`) en Python
#
# Las **cadenas de texto** (tipo `str`) son uno de los tipos de datos más utilizados en Python.
# Existen varias funciones y métodos que nos permiten **analizar, modificar o transformar** textos fácilmente.
#
# ---
#
# # 📏 1. Función `len()`
#
# La función `len()` devuelve la **cantidad de caracteres** de una cadena,
# incluyendo letras, espacios, números y signos.
#
# 📘 **Ejemplo:**
# ```python
# frase = "Hola mundo"
# print(len(frase))
# ```
#
# 📤 **Salida:**
# ```
# 10
# ```
#
# 💡 *Se cuentan 10 porque incluye el espacio entre “Hola” y “mundo”.*
#
# ---
#
# # 🔁 2. Método `replace()`
#
# El método `.replace()` **reemplaza un texto por otro** dentro de una cadena.
# No modifica la original, sino que devuelve una **nueva cadena modificada**.
#
# 📘 **Sintaxis:**
# ```python
# cadena.replace("texto_a_reemplazar", "nuevo_texto")
# ```
#
# 📘 **Ejemplo:**
# ```python
# frase = "Me gusta Java"
# nueva_frase = frase.replace("Java", "Python")
# print(nueva_frase)
# ```
#
# 📤 **Salida:**
# ```
# Me gusta Python
# ```
#
# ---
#
# # ✂️ 3. Método `split()`
#
# El método `.split()` **divide una cadena en partes** (una lista) usando un **separador**.
# Por defecto, separa por **espacios**.
#
# 📘 **Ejemplo:**
# ```python
# frase = "Aprender Python es divertido"
# palabras = frase.split()
# print(palabras)
# ```
#
# 📤 **Salida:**
# ```
# ['Aprender', 'Python', 'es', 'divertido']
# ```
#
# 👉 También puedes usar otro separador:
# ```python
# texto = "uno,dos,tres"
# print(texto.split(","))
# ```
#
# 📤 **Salida:**
# ```
# ['uno', 'dos', 'tres']
# ```
#
# ---
#
# # 🔗 4. Método `join()`
#
# El método `.join()` **une los elementos de una lista** en una sola cadena,
# colocando un texto (como espacio o coma) entre cada elemento.
#
# 📘 **Ejemplo:**
# ```python
# palabras = ["Hola", "mundo", "Python"]
# frase = " ".join(palabras)
# print(frase)
# ```
#
# 📤 **Salida:**
# ```
# Hola mundo Python
# ```
#
# 💡 Si usas una coma:
# ```python
# print(", ".join(palabras))
# ```
#
# 📤 **Salida:**
# ```
# Hola, mundo, Python
# ```
#
# ---
#
# # 🔠 5. Método `upper()`
#
# Convierte **todas las letras de la cadena a mayúsculas**.
#
# 📘 **Ejemplo:**
# ```python
# texto = "hola mundo"
# print(texto.upper())
# ```
#
# 📤 **Salida:**
# ```
# HOLA MUNDO
# ```
#
# ---
#
# # 🔡 6. Método `lower()`
#
# Convierte **todas las letras de la cadena a minúsculas**.
#
# 📘 **Ejemplo:**
# ```python
# texto = "PYTHON ES GENIAL"
# print(texto.lower())
# ```
#
# 📤 **Salida:**
# ```
# python es genial
# ```
#
# ---
#
# # 🔤 7. Método `capitalize()`
#
# Convierte **solo la primera letra** de la cadena en mayúscula y las demás en minúsculas.
#
# 📘 **Ejemplo:**
# ```python
# texto = "bIENVENIDO a python"
# print(texto.capitalize())
# ```
#
# 📤 **Salida:**
# ```
# Bienvenido a python
# ```
#
# ---
#
# # 🔠 8. Método `isupper()`
#
# Devuelve `True` si **todas las letras** de la cadena están en **mayúscula**,
# y `False` en caso contrario.
#
# 📘 **Ejemplo:**
# ```python
# texto = "HOLA"
# print(texto.isupper())
#
# texto2 = "Hola"
# print(texto2.isupper())
# ```
#
# 📤 **Salida:**
# ```
# True
# False
# ```
#
# ---
#
# # 🔡 9. Método `islower()`
#
# Devuelve `True` si **todas las letras** están en **minúscula**,
# y `False` en caso contrario.
#
# 📘 **Ejemplo:**
# ```python
# texto = "python"
# print(texto.islower())
#
# texto2 = "Python"
# print(texto2.islower())
# ```
#
# 📤 **Salida:**
# ```
# True
# False
# ```
#
# ---
#
# # 🧠 En resumen
#
# | Método / Función | Acción que realiza | Ejemplo | Resultado |
# |------------------|-------------------|----------|------------|
# | `len()` | Devuelve la cantidad de caracteres | `len("Hola")` | `4` |
# | `.replace()` | Reemplaza texto | `"Hola".replace("H","M")` | `"Mola"` |
# | `.split()` | Divide texto en partes (lista) | `"a,b,c".split(",")` | `['a', 'b', 'c']` |
# | `.join()` | Une elementos de una lista en una cadena | `" ".join(['a','b'])` | `"a b"` |
# | `.upper()` | Convierte todo a mayúsculas | `"hola".upper()` | `"HOLA"` |
# | `.lower()` | Convierte todo a minúsculas | `"HOLA".lower()` | `"hola"` |
# | `.capitalize()` | Primera letra en mayúscula | `"python".capitalize()` | `"Python"` |
# | `.isupper()` | Verifica si todo está en mayúsculas | `"HOLA".isupper()` | `True` |
# | `.islower()` | Verifica si todo está en minúsculas | `"hola".islower()` | `True` |
#
# ---
#
# # 💡 Reto de práctica
#
# 1. Pide al usuario una frase.
# 2. Muestra:
#    - Cuántos caracteres tiene (`len`).
#    - La frase en **mayúsculas** y en **minúsculas**.
#    - La frase con la **primera letra en mayúscula**.
# 3. Reemplaza todas las letras `"a"` por `"@"` con `.replace()`.
# 4. Divide la frase en palabras con `.split()` y luego vuelve a unirlas con guiones usando `.join()`.
#
# 👉 Ejemplo de salida:
# ```
# Ingrese una frase: Aprender Python es divertido
# Cantidad de caracteres: 28
# MAYÚSCULAS: APRENDER PYTHON ES DIVERTIDO
# minúsculas: aprender python es divertido
# Capitalizada: Aprender python es divertido
# Reemplazo de a: Aprender Python es divertido → @prender Python es divertido
# Lista de palabras: ['Aprender', 'Python', 'es', 'divertido']
# Unidas con guiones: Aprender-Python-es-divertido
# ```

# %% [markdown]
# # 📘 Ejercicios básicos con cadenas de texto (`str`) en Python
#
# ---
#
# ### 📝 Ejercicio 1: Saludo personalizado
# Pide al usuario su **nombre** y **apellido**,
# y muestra un saludo completo utilizando **concatenación de cadenas**.
#
# 📘 **Ejemplo:**
# ```python
# nombre = input("Ingrese su nombre: ")
# apellido = input("Ingrese su apellido: ")
#
# saludo = "Hola " + nombre + " " + apellido + ", ¡bienvenido a Python!"
# print(saludo)
# ```
#
# 📤 **Salida:**
# ```
# Ingrese su nombre: Carlos
# Ingrese su apellido: Tamayo
# Hola Carlos Tamayo, ¡bienvenido a Python!
# ```
#
# ---
#
# ### 📝 Ejercicio 2: Contar caracteres
# Crea un programa que pida una **palabra o frase** y muestre
# cuántos caracteres tiene usando la función `len()`.
#
# 📘 **Ejemplo:**
# ```python
# frase = input("Escriba una frase: ")
# longitud = len(frase)
# print("La frase tiene", longitud, "caracteres.")
# ```
#
# 📤 **Salida:**
# ```
# Escriba una frase: Me gusta programar
# La frase tiene 18 caracteres.
# ```
#
# ---
#
# ### 📝 Ejercicio 3: Mayúsculas y minúsculas
# Pide al usuario una palabra y muestra:
# - La palabra en **mayúsculas** con `.upper()`
# - La palabra en **minúsculas** con `.lower()`
# - Solo la **primera letra en mayúscula** con `.capitalize()`
#
# 📘 **Ejemplo:**
# ```python
# palabra = input("Escriba una palabra: ")
#
# print("En mayúsculas:", palabra.upper())
# print("En minúsculas:", palabra.lower())
# print("Capitalizada:", palabra.capitalize())
# ```
#
# 📤 **Salida:**
# ```
# Escriba una palabra: python
# En mayúsculas: PYTHON
# En minúsculas: python
# Capitalizada: Python
# ```
#
# ---
#
# # 💡 Reto adicional
# Pide al usuario su **nombre completo** y muestra:
# 1. Su nombre en **mayúsculas**
# 2. Cuántas letras tiene su nombre (sin contar espacios)
# 3. La **primera letra** y la **última letra** del nombre
#
# 👉 Usa `len()`, `replace()`, y la indexación de cadenas `[0]` y `[-1]`.
